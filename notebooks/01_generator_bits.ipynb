# %% [markdown]
# ### 1. Generador de Bits
#
# El primer paso en la cadena de transmisión es generar la fuente de datos. Crearemos una secuencia de bits binarios aleatorios $(b_0, b_1, \dots, b_{L-1})$ donde $b_i \in \{0, 1\}$.
#
# La longitud total de la secuencia de bits, $L_{bits}$, se determina por el número de símbolos OFDM que queremos simular (`N_sym`), el número de subportadoras (`N`) y el número de bits por símbolo de la constelación (`mu`):
#
# $$ L_{bits} = N_{sym} \times N \times \mu $$
#
# Usaremos el generador de números aleatorios de NumPy (`RNG`) que inicializamos en los parámetros para asegurar la reproducibilidad de los resultados.

# %%
# notebooks/01_generador_bits.ipynb

# --- Importaciones ----------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt

# Importar nuestros módulos locales
# (Asegúrate de tener la carpeta 'src' en el path o haber instalado el paquete)
import sys
sys.path.append('../') # Añadir el directorio padre para poder importar 'src'
from src.ofdm_tf import params as p

print("✅ Módulos y parámetros importados.")
print(f"Se simularán {p.N_sym} símbolos OFDM.")
